# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import sklearn as sk

# %%
housing_data = pd.read_csv('/Users/peytonbailey/WGU Data Science Masters/D600- Statistical Data Mining/Task 1/D600 Task 1 Dataset 1 Housing Information.csv')

# %%
print(housing_data.columns)
housing_data['IsLuxury'] = housing_data['IsLuxury'].astype('category')
housing_data['Garage'].dtype
# Out:
# Index(['ID', 'Price', 'SquareFootage', 'NumBathrooms', 'NumBedrooms',
#        'BackyardSpace', 'CrimeRate', 'SchoolRating', 'AgeOfHome',
#        'DistanceToCityCenter', 'EmploymentRate', 'PropertyTaxRate',
#        'RenovationQuality', 'LocalAmenities', 'TransportAccess', 'Fireplace',
#        'HouseColor', 'Garage', 'Floors', 'Windows', 'PreviousSalePrice',
#        'IsLuxury'],
#       dtype='object')
# dtype('O')

# %%
print(housing_data['SquareFootage'].describe())
print(housing_data['NumBathrooms'].describe())
print(housing_data['NumBedrooms'].describe())
# Out:
# count    7000.000000
# mean     1048.947459
# std       426.010482
# min       550.000000
# 25%       660.815000
# 50%       996.320000
# 75%      1342.292500
# max      2874.700000
# Name: SquareFootage, dtype: float64
# count    7000.000000
# mean        2.131397
# std         0.952561
# min         1.000000
# 25%         1.290539
# 50%         1.997774
# 75%         2.763997
# max         5.807239
# Name: NumBathrooms, dtype: float64
# count    7000.000000
# mean        3.008571
# std         1.021940
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         7.000000
# Name: NumBedrooms, dtype: float64

# %%
print(housing_data['CrimeRate'].describe())
print(housing_data['SchoolRating'].describe())
print(housing_data['AgeOfHome'].describe())
# Out:
# count    7000.000000
# mean       31.226194
# std        18.025327
# min         0.030000
# 25%        17.390000
# 50%        30.385000
# 75%        43.670000
# max        99.730000
# Name: CrimeRate, dtype: float64
# count    7000.000000
# mean        6.942923
# std         1.888148
# min         0.220000
# 25%         5.650000
# 50%         7.010000
# 75%         8.360000
# max        10.000000
# Name: SchoolRating, dtype: float64
# count    7000.000000
# mean       46.797046
# std        31.779701
# min         0.010000
# 25%        20.755000
# 50%        42.620000
# 75%        67.232500
# max       178.680000
# Name: AgeOfHome, dtype: float64

# %%
print(housing_data['RenovationQuality'].describe())
# Out:
# count    7000.000000
# mean        5.003357
# std         1.970428
# min         0.010000
# 25%         3.660000
# 50%         5.020000
# 75%         6.350000
# max        10.000000
# Name: RenovationQuality, dtype: float64

# %%
pd.options.display.float_format = '{:,.2f}'.format
print(housing_data['Price'].describe())
print(housing_data['PreviousSalePrice'].describe())
pd.reset_option('display.float_format')
# Out:
# count       7,000.00
# mean      307,281.97
# std       150,173.43
# min        85,000.00
# 25%       192,107.53
# 50%       279,322.95
# 75%       391,878.13
# max     1,046,675.64
# Name: Price, dtype: float64
# count       7,000.00
# mean      284,509.35
# std       185,734.02
# min        -8,356.90
# 25%       142,013.98
# 50%       262,183.13
# 75%       396,121.17
# max     1,296,606.69
# Name: PreviousSalePrice, dtype: float64

# %%
garage_counts = housing_data['Garage'].value_counts()
garage_ratios = housing_data['Garage'].value_counts(normalize=True) 

# Create summary table
summary_table = pd.DataFrame({'Frequency': garage_counts, 'Ratios': garage_ratios})

print(summary_table)
# Out:
#         Frequency    Ratios
# Garage
# No           4488  0.641143
# Yes          2512  0.358857

# %%
lux_counts = housing_data['IsLuxury'].value_counts()
lux_ratios = housing_data['IsLuxury'].value_counts(normalize=True) 

# Create summary table
lux_summary_table = pd.DataFrame({'Frequency': lux_counts, 'Ratios': lux_ratios})

print(lux_summary_table)
# Out:
#           Frequency  Ratios
# IsLuxury
# 1              3528   0.504
# 0              3472   0.496

# %%
ax = housing_data['SquareFootage'].hist()
ax.set_title('Distribution of Square Footage')
ax.set_xlabel('Square Footage')
ax.set_ylabel('Frequency')
plt.show()

# %%
ax = housing_data['NumBathrooms'].hist(color='green')
ax.set_title('Distribution of Number of Bathrooms')
ax.set_xlabel('Number of Bathrooms')
ax.set_ylabel('Frequency')
plt.show()

# %%
ax = housing_data['NumBedrooms'].hist(color='orange')
ax.set_title('Distribution of Number of Bedrooms')
ax.set_xlabel('Number of Bedrooms')
ax.set_ylabel('Frequency')
plt.show()

# %%
ax = housing_data['CrimeRate'].hist(color='red')
ax.set_title('Distribution of Crime Rate')
ax.set_xlabel('Crime Rate')
ax.set_ylabel('Frequency')
plt.show()

# %%
ax = housing_data['SchoolRating'].hist(color='orange')
ax.set_title('Distribution of School Rating')
ax.set_xlabel('School Rating')
ax.set_ylabel('Frequency')
plt.show()

# %%
ax = housing_data['AgeOfHome'].hist(color='purple')
ax.set_title('Distribution of Age of Home')
ax.set_xlabel('Age')
ax.set_ylabel('Frequency')
plt.show()

# %%
ax = housing_data['RenovationQuality'].hist(color='teal')
ax.set_title('Distribution of Renovation Quality')
ax.set_xlabel('Renovation Quality')
ax.set_ylabel('Frequency')
plt.show()

# %%
ax = housing_data['PreviousSalePrice'].hist(color='pink')
ax.set_title('Distribution of Previous Sale Price')
ax.set_xlabel('Previous Sale Price')
ax.set_ylabel('Frequency')
plt.ticklabel_format(style='plain', axis='x')
plt.show()

# %%
ax = housing_data['Price'].hist(color='green')
ax.set_title('Distribution of Price')
ax.set_xlabel('Price')
ax.set_ylabel('Frequency')
plt.ticklabel_format(style='plain', axis='x')
plt.show()

# %%
sns.countplot(x ='Garage', data = housing_data)
plt.show()

# %%
sns.countplot(x ='IsLuxury', data = housing_data, color = 'green')
plt.show()

# %%
housing_data.plot(kind = 'scatter', x = 'SquareFootage', y= 'Price')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
housing_data.plot(kind = 'scatter', x = 'NumBathrooms', y= 'Price')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
sns.boxplot(x='NumBedrooms', y='Price', data=housing_data)

plt.xlabel('Number of Bedrooms')
plt.ylabel('Housing Price')
plt.title('Box Plot of Housing Prices by Number of Bedrooms')
plt.ticklabel_format(style='plain', axis='y')

plt.show()

# %%
housing_data.plot(kind = 'scatter', x = 'CrimeRate', y= 'Price')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
housing_data.plot(kind = 'scatter', x = 'SchoolRating', y= 'Price')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
housing_data.plot(kind = 'scatter', x = 'AgeOfHome', y= 'Price')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
sns.boxplot(x='Garage', y='Price', data=housing_data)
plt.xlabel('Garage?')
plt.ylabel('Housing Price')
plt.title('Box Plot of Housing Prices by Presence or Absence of Garage')
plt.ticklabel_format(style='plain', axis='y')

plt.show()

# %%
sns.boxplot(x='IsLuxury', y='Price', data=housing_data)

plt.xlabel('Luxury or Not')
plt.ylabel('Housing Price')
plt.title('Box Plot of Housing Prices by Luxury')
plt.ticklabel_format(style='plain', axis='y')

plt.show()

# %%
housing_data.plot(kind = 'scatter', x = 'PreviousSalePrice', y= 'Price', color='green')
plt.ticklabel_format(style='plain', axis='x')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
housing_data.plot(kind = 'scatter', x = 'RenovationQuality', y= 'Price', color='orange')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
housing_data.columns
# Out:
# Index(['ID', 'Price', 'SquareFootage', 'NumBathrooms', 'NumBedrooms',
#        'BackyardSpace', 'CrimeRate', 'SchoolRating', 'AgeOfHome',
#        'DistanceToCityCenter', 'EmploymentRate', 'PropertyTaxRate',
#        'RenovationQuality', 'LocalAmenities', 'TransportAccess', 'Fireplace',
#        'HouseColor', 'Garage', 'Floors', 'Windows', 'PreviousSalePrice',
#        'IsLuxury'],
#       dtype='object')

# %%
df = housing_data
df['Garage'] = df['Garage'].astype('category')
df['IsLuxury'] = df['IsLuxury'].astype('category')
df['Garage'] = df['Garage'].astype(str)
df['IsLuxury'] = df['IsLuxury'].astype(str)
df_encoded = pd.get_dummies(df, columns=['Garage', 'IsLuxury'], drop_first=True)


df_encoded['Garage_Yes'] = df_encoded['Garage_Yes'].astype(int)
df_encoded['IsLuxury_1'] = df_encoded['IsLuxury_1'].astype(int)

print(df_encoded.head())
# Out:
#      ID        Price  SquareFootage  NumBathrooms  NumBedrooms  BackyardSpace  \
# 0  4922  255614.8992         566.62      1.000000            4         779.42
# 1  5009  155586.0947        1472.34      1.000000            2         656.13
# 2  4450  131050.8324         550.00      1.779354            3         754.57
# 3  1070  151361.7125         941.81      2.035254            2         439.59
# 4   400  113167.6128         550.00      1.064644            3         353.03
#
#    CrimeRate  SchoolRating  AgeOfHome  DistanceToCityCenter  ...  \
# 0      20.56          5.62      39.46                 10.08  ...
# 1      15.62          5.63      40.51                  7.89  ...
# 2      12.47          9.20      48.38                 23.74  ...
# 3      22.22          7.08      94.67                  5.22  ...
# 4       8.28          5.93      16.80                 43.13  ...
#
#    RenovationQuality  LocalAmenities  TransportAccess  Fireplace  HouseColor  \
# ...

# %%
X = df_encoded[['SquareFootage', 'NumBathrooms', 'NumBedrooms','RenovationQuality', 'PreviousSalePrice','CrimeRate', 'SchoolRating', 'AgeOfHome', 'Garage_Yes','IsLuxury_1']]
y = df_encoded['Price']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=22)

# %%
train_df = pd.concat([X_train, y_train], axis=1)
test_df = pd.concat([X_test, y_test], axis=1)
train_df.to_csv('training_data.csv', index=False)
test_df.to_csv('testing_data.csv', index=False)

# %%
X_train = sm.add_constant(X_train)
model = sm.OLS(y_train, X_train).fit()
print("=== Initial Model ===")
print(model.summary())
# Out:
# === Initial Model ===
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.736
# Model:                            OLS   Adj. R-squared:                  0.735
# Method:                 Least Squares   F-statistic:                     1558.
# Date:                Wed, 16 Apr 2025   Prob (F-statistic):               0.00
# Time:                        18:14:25   Log-Likelihood:                -70966.
# No. Observations:                5600   AIC:                         1.420e+05
# Df Residuals:                    5589   BIC:                         1.420e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const              1.826e+04   6605.578      2.764      0.006    5308.039    3.12e+04
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# Calculate VIF for each feature
vif_data = pd.DataFrame()
vif_data['Feature'] = X_train.columns
vif_data['VIF'] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
print(vif_data)
# Out:
#               Feature        VIF
# 0               const  40.972903
# 1       SquareFootage   1.841923
# 2        NumBathrooms   1.514266
# 3         NumBedrooms   1.730682
# 4   RenovationQuality   1.620105
# 5   PreviousSalePrice   3.414047
# 6           CrimeRate   1.037464
# 7        SchoolRating   1.547736
# 8           AgeOfHome   1.031033
# 9          Garage_Yes   1.001877
# 10         IsLuxury_1   1.475693

# %%
def backward_elimination_with_vif(X, y, vif_threshold=10, p_threshold=0.05):
    features = X.columns.tolist()
    
    while True:
        if not features:  # Exit if no features remain
            break
        
        # Calculate VIF for features BEFORE adding constant
        vif = pd.DataFrame()
        vif["Variable"] = features
        vif["VIF"] = [variance_inflation_factor(X[features].values, i) for i in range(len(features))]
        
        # Only add constant for model fitting AFTER VIF calculation
        X_const = sm.add_constant(X[features])
        model = sm.OLS(y, X_const).fit()
        
        # Remove feature with highest VIF if it exceeds threshold
        max_vif = vif["VIF"].max()
        if max_vif > vif_threshold:
            max_vif_row = vif.loc[vif['VIF'].idxmax()]
            removed_feature = max_vif_row['Variable']
            features.remove(removed_feature)
            print(f'Removed "{removed_feature}" (VIF: {max_vif:.2f})')
            continue  # Restart loop to recalculate VIF with updated features
        
        # If no high-VIF features, check p-values (excluding intercept)
        p_values = model.pvalues.iloc[1:]  # Skip intercept's p-value
        max_p = p_values.max()
        
        if max_p > p_threshold:
            removed_feature = p_values.idxmax()
            features.remove(removed_feature)
            print(f'Removed "{removed_feature}" (p-value: {max_p:.4f})')
        else:
            break  # Exit when all features are significant
    
    return features

# %%
optimal_features = backward_elimination_with_vif(X_train, y_train)
# Out:
# Removed "const" (VIF: 40.97)
# Removed "SchoolRating" (VIF: 19.47)
# Removed "RenovationQuality" (VIF: 10.16)
# Removed "Garage_Yes" (p-value: 0.8790)
# Removed "CrimeRate" (p-value: 0.4000)

# %%
# Final model
X_train_final = sm.add_constant(X_train[optimal_features])
final_model = sm.OLS(y_train, X_train_final).fit()

print("\n=== Final Model Summary ===")
print(final_model.summary())
# Out:
# === Final Model Summary ===
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.735
# Model:                            OLS   Adj. R-squared:                  0.735
# Method:                 Least Squares   F-statistic:                     2588.
# Date:                Wed, 16 Apr 2025   Prob (F-statistic):               0.00
# Time:                        18:14:26   Log-Likelihood:                -70974.
# No. Observations:                5600   AIC:                         1.420e+05
# Df Residuals:                    5593   BIC:                         1.420e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const              2.048e+04   5649.690      3.624      0.000    9401.341    3.16e+04
# ...

# %%
coefficients = final_model.params

# Print regression equation
equation = "Price = "
for i, coef in enumerate(coefficients):
    if i == 0:  # Intercept
        equation += f"{coef:.2f} + "
    else:
        equation += f"{coef:.2f}*{coefficients.index[i]} + "
equation = equation.rstrip(" + ")
print("\n=== Multiple Linear Regression Equation ===")
print(equation)
# Out:
# === Multiple Linear Regression Equation ===
# Price = 20476.93 + 50.91*SquareFootage + 18013.65*NumBathrooms + 17348.64*NumBedrooms + 0.39*PreviousSalePrice + -93.04*AgeOfHome + 69768.87*IsLuxury_1

# %%
from sklearn.metrics import mean_squared_error

# Generate predictions for the training set
y_train_pred = final_model.predict(X_train_final)

# Calculate MSE using sklearn
mse_train = mean_squared_error(y_train, y_train_pred)

# Print MSE
print(f"Mean Squared Error on Training Set: {mse_train:.4f}")
# Out:
# Mean Squared Error on Training Set: 5969309812.8282

# %%
X_test_final = X_test[optimal_features]

# Add constant to test data
X_test_final = sm.add_constant(X_test_final)

# Generate predictions using the optimized model
y_pred = final_model.predict(X_test_final)

mse_test = mean_squared_error(y_test, y_pred)
# Print predictions
print("\n=== Predictions on Test Data ===")
print(y_pred)
print(f"Mean Squared Error on Test Set: {mse_test:.4f}")
# Out:
# === Predictions on Test Data ===
# 5854    343918.142356
# 709     325322.111549
# 759     168660.987614
# 6152    552637.321276
# 68      113002.622638
#             ...
# 5464    285585.252763
# 375     238507.437306
# 6275    376581.501225
# 3732    503708.297024
# 1338    219291.368767
# Length: 1400, dtype: float64
# Mean Squared Error on Test Set: 6011563127.2063

# %%
mse_train - mse_test
# Out:
# -42253314.37809467

# %%
from scipy.stats import ttest_ind

train_squared_errors = (y_train - y_train_pred) ** 2
test_squared_errors = (y_test - y_pred) ** 2

# Perform two-sample t-test
t_stat, p_value = ttest_ind(train_squared_errors, test_squared_errors)

# Print results
print(f"Training MSE: {mean_squared_error(y_train, y_train_pred):.4f}")
print(f"Test MSE: {mean_squared_error(y_test, y_pred):.4f}")
print(f"T-statistic: {t_stat:.4f}, P-value: {p_value:.4f}")
# Out:
# Training MSE: 5969309812.8282
# Test MSE: 6011563127.2063
# T-statistic: -0.1159, P-value: 0.9078

# %%
from statsmodels.stats.stattools import durbin_watson

# Durbin-Watson test
dw_stat = durbin_watson(final_model.resid)
print(f'Durbin-Watson Statistic: {dw_stat}')
# Out:
# Durbin-Watson Statistic: 2.0171492222805805

# %%
import scipy.stats as stats

# Q-Q plot
stats.probplot(final_model.resid, dist="norm", plot=plt)
plt.title('Q-Q Plot')
plt.show()

# %%
# Residuals vs. Predicted values scatter plot
sns.scatterplot(x=final_model.fittedvalues, y=final_model.resid)
plt.axhline(0, color='red', linestyle='--')
plt.title('Homoscedasticity Check')
plt.show()
